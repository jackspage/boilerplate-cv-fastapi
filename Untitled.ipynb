# %%
import pandas as pd

# %%
name = f"/storage/export_success.jpg"

pd.DataFrame([{'a': 1}]).to_csv(name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-25cea21ed1ee> in <module>
#       1 name = f"/storage/export_success.jpg"
#       2
# ----> 3 pd.DataFrame([{'a': 1}]).to_csv(name)
#
# ~/Github/BERT_TF2/venv/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# ~/Github/BERT_TF2/venv/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
# ...
